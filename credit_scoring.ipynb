// %% [markdown]
// # Load Brunel library and others

// %%
%AddJar -magic file:///u/wmlscors/iml-library/brunel/spark-kernel-brunel-all-2.3.jar -f
// Out:
// Starting download from file:///u/wmlscors/iml-library/brunel/spark-kernel-brunel-all-2.3.jar
// Finished download of spark-kernel-brunel-all-2.3.jar

// %%
import org.apache.spark.ml.feature.{StringIndexer,IndexToString, VectorIndexer, VectorAssembler}
import org.apache.spark.ml.regression.LinearRegression
import org.apache.spark.ml.classification.LogisticRegression
import com.ibm.analytics.ngp.ingest.Sampling
import com.ibm.analytics.ngp.pipeline._
import org.apache.spark.ml.PipelineStage
import com.ibm.analytics.ngp.util._
import org.apache.spark.ml.classification.BinaryLogisticRegressionSummary

// %% [markdown]
// # Load DB2 Data into DataFrame

// %%
val jdbcUser = sys.env("SFJDBC_USER")
val jdbcPass = sys.env("SFJDBC_PASS")
val jdbcHost = sys.env("SFJDBC_HOST")
val jdbcUrl = "jdbc:db2://" + jdbcHost + ":448/RDBNDW00"  
val df = spark.read.format("jdbc").options(Map(
"driver" -> "com.ibm.db2.jcc.DB2Driver",
"url" -> jdbcUrl,
"user" -> jdbcUser,
"password" -> jdbcPass,
"dbtable" -> "MLZ.CRDATA")).load()

// %%
df.show(5)
// Out:
// +------+---+------+-----+-----------------+--------+----------------+
// |RATING|AGE|INCOME|CARDS|        EDUCATION|CARLOANS|CREDITREIMBURSED|
// +------+---+------+-----+-----------------+--------+----------------+
// |    50| 31| 10018|    5|Elementary school|       2|               1|
// |    50| 28| 10053|    3|Elementary school|       2|               0|
// |   820| 27| 10179|    3|Elementary school|       2|               0|
// |    50| 44| 10204|    5|Elementary school|       2|               0|
// |    50| 26| 10267|    3|Elementary school|       2|               0|
// +------+---+------+-----+-----------------+--------+----------------+
// only showing top 5 rows

// %%
print(sys.env("SFJDBC_PASS"))
print(sys.env("SFJDBC_USER"))
print(sys.env("SFJDBC_HOST"))
// Out:
// rad1oheaSTEFzb01

// %% [markdown]
// # Analyse Data

// %%
%%brunel 
data('df') bar x(Age) y(CreditReimbursed) mean(CreditReimbursed) stack axes(x:'Age' ,y:'Percent of reimbursed credit') tooltip(#all)
// Out:
//          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/brunel.2.3.css" charset="utf-8">
//          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/sumoselect.css" charset="utf-8">
//          <style>  </style>
//          <div id="controlsId46da3533-96fe-4836-81a1-13d3cd8c45a9" class="brunel"/>
// <svg id="visid421cb2f4-6064-439e-9be4-a62651b11add" width="500" height="400"></svg>
//
// <script>
// require.config({
//             waitSeconds: 60,
//             paths: {
//                 'd3': '//cdnjs.cloudflare.com/ajax/libs/d3/4.2.1/d3.min',
//                 'topojson' : '//cdnjs.cloudflare.com/ajax/libs/topojson/1.6.20/topojson.min',
//                 'brunel' : 'https://brunelvis.org/js/brunel.2.3.min',
//                 'brunelControls' : 'https://brunelvis.org/js/brunel.controls.2.3.min'
//             },
//
//             shim: {
//                'brunel' : {
//                     exports: 'BrunelD3',
//                     deps: ['d3', 'topojson'],
//                     init: function() {
//                        return {
//                          BrunelD3 : BrunelD3,
//                          BrunelData : BrunelData
//                       }
//                     }
//                 },
//                'brunelControls' : {
//                     exports: 'BrunelEventHandlers',
//                     init: function() {
//                        return {
//                          BrunelEventHandlers: BrunelEventHandlers,
//                          BrunelJQueryControlFactory: BrunelJQueryControlFactory
//                       }
//                     }
//                 }
//
//             }
//
//         });
//
//         require(["d3"], function(d3) {
//         require(["brunel", "brunelControls"], function(brunel, brunelControls) {
//
//             function  BrunelVis(visId) {
//   "use strict";                                                                       // strict mode
//   var datasets = [],                                      // array of datasets for the original data
//       pre = function(d, i) { return d },                         // default pre-process does nothing
//       post = function(d, i) { return d },                       // default post-process does nothing
//       transitionTime = 200,                                        // transition time for animations
//       charts = [],                                                       // the charts in the system
//       vis = d3.select('#' + visId).attr('class', 'brunel');                     // the SVG container
//
//   BrunelD3.addDefinitions(vis);                                   // ensure standard symbols present
//
//   // Define chart #1 in the visualization //////////////////////////////////////////////////////////
//
//   charts[0] = function(parentNode, filterRows) {
//     var geom = BrunelD3.geometry(parentNode || vis.node(), 0, 0, 1, 1, 5, 43, 37, 13),
//       elements = [];                                              // array of elements in this chart
//
//     // Define groups for the chart parts ///////////////////////////////////////////////////////////
//
//     var chart =  vis.append('g').attr('class', 'chart1')
//       .attr('transform','translate(' + geom.chart_left + ',' + geom.chart_top + ')');
//     var overlay = chart.append('g').attr('class', 'element').attr('class', 'overlay');
//     var zoom = d3.zoom().scaleExtent([1/3,3]);
//     var zoomNode = overlay.append('rect').attr('class', 'overlay')
//       .attr('x', geom.inner_left).attr('y', geom.inner_top)
//       .attr('width', geom.inner_rawWidth).attr('height', geom.inner_rawHeight)
//       .style('cursor', 'move').call(zoom)
//       .node();
//     zoomNode.__zoom = d3.zoomIdentity;
//     chart.append('rect').attr('class', 'background').attr('width', geom.chart_right-geom.chart_left).attr('height', geom.chart_bottom-geom.chart_top);
//     var interior = chart.append('g').attr('class', 'interior zoomNone')
//       .attr('transform','translate(' + geom.inner_left + ',' + geom.inner_top + ')')
//       .attr('clip-path', 'url(#clip_visid421cb2f4-6064-439e-9be4-a62651b11add_chart1_inner)');
//     interior.append('rect').attr('class', 'inner').attr('width', geom.inner_width).attr('height', geom.inner_height);
//     var gridGroup = interior.append('g').attr('class', 'grid');
//     var axes = chart.append('g').attr('class', 'axis')
//       .attr('transform','translate(' + geom.inner_left + ',' + geom.inner_top + ')');
//     vis.append('clipPath').attr('id', 'clip_visid421cb2f4-6064-439e-9be4-a62651b11add_chart1_inner').append('rect')
//       .attr('x', 0).attr('y', 0)
//       .attr('width', geom.inner_rawWidth+1).attr('height', geom.inner_rawHeight+1);
//
//     // Scales //////////////////////////////////////////////////////////////////////////////////////
//
//     var scale_x = d3.scaleLinear().domain([15, 65.000005])
//       .range([0, geom.inner_width]);
//     var scale_inner = d3.scaleLinear().domain([0,1])
//       .range([-0.5, 0.5]);
//     var scale_y = d3.scaleLinear().domain([0, 1.0000001])
//       .range([geom.inner_height, 0]);
//     var base_scales = [scale_x, scale_y];                           // untransformed original scales
//
//     // Axes ////////////////////////////////////////////////////////////////////////////////////////
//
//     axes.append('g').attr('class', 'x axis')
//       .attr('transform','translate(0,' + geom.inner_rawHeight + ')')
//       .attr('clip-path', 'url(#clip_visid421cb2f4-6064-439e-9be4-a62651b11add_chart1_haxis)');
//     vis.append('clipPath').attr('id', 'clip_visid421cb2f4-6064-439e-9be4-a62651b11add_chart1_haxis').append('polyline')
//       .attr('points', '-1,-1000, -1,-1 -5,5, -1000,5, -100,1000, 10000,1000 10000,-1000');
//     axes.select('g.axis.x').append('text').attr('class', 'title').text('Age').style('text-anchor', 'middle')
//       .attr('x',geom.inner_rawWidth/2)
//       .attr('y', geom.inner_bottom - 2.0).attr('dy','-0.27em');
//     axes.append('g').attr('class', 'y axis')
//       .attr('clip-path', 'url(#clip_visid421cb2f4-6064-439e-9be4-a62651b11add_chart1_vaxis)');
//     vis.append('clipPath').attr('id', 'clip_visid421cb2f4-6064-439e-9be4-a62651b11add_chart1_vaxis').append('polyline')
//       .attr('points', '-1000,-10000, 10000,-10000, 10000,' + (geom.inner_rawHeight+1) + ', -1,' + (geom.inner_rawHeight+1) + ', -1,' + (geom.inner_rawHeight+5) + ', -1000,' + (geom.inner_rawHeight+5) );
//     axes.select('g.axis.y').append('text').attr('class', 'title').text('Percent of reimbursed credit').style('text-anchor', 'middle')
//       .attr('x',-geom.inner_rawHeight/2)
//       .attr('y', 4-geom.inner_left).attr('dy', '0.7em').attr('transform', 'rotate(270)');
//
//     var axis_bottom = d3.axisBottom(scale_x).ticks(Math.min(10, Math.round(geom.inner_width / 33.0)));
//     var axis_left = d3.axisLeft(scale_y).ticks(Math.min(10, Math.round(geom.inner_width / 20)));
//
//     function buildAxes(time) {
//       var axis_x = axes.select('g.axis.x');
//       BrunelD3.transition(axis_x, time).call(axis_bottom.scale(scale_x));
//       var axis_y = axes.select('g.axis.y');
//       BrunelD3.transition(axis_y, time).call(axis_left.scale(scale_y));
//     }
//     zoom.on('zoom', function(t, time) {
//         t = t ||BrunelD3.restrictZoom(d3.event.transform, geom, this);
//         scale_x = t.rescaleX(base_scales[0]);
//         scale_y = t.rescaleY(base_scales[1]);
//         zoomNode.__zoom = t;
//         interior.attr('class', 'interior ' + BrunelD3.zoomLabel(t.k));;
//         build(time || -1);
//     });
//
//     // Define element #1 ///////////////////////////////////////////////////////////////////////////
//
//     elements[0] = function() {
//       var original, processed,                           // data sets passed in and then transformed
//         element, data,                                 // brunel element information and brunel data
//         selection, merged;                                      // d3 selection and merged selection
//       var elementGroup = interior.append('g').attr('class', 'element1'),
//         main = elementGroup.append('g').attr('class', 'main'),
//         labels = BrunelD3.undoTransform(elementGroup.append('g').attr('class', 'labels').attr('aria-hidden', 'true'), eleme

// %%
%%brunel 
data('df') x(Age) y(income) color(CreditReimbursed) tooltip(#all)
// Out:
//          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/brunel.2.3.css" charset="utf-8">
//          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/sumoselect.css" charset="utf-8">
//          <style>  </style>
//          <div id="controlsId0263896b-750d-4d21-968c-e991143e13a0" class="brunel"/>
// <svg id="visiddc72168b-af3f-4e53-b0d4-687ee816c534" width="500" height="400"></svg>
//
// <script>
// require.config({
//             waitSeconds: 60,
//             paths: {
//                 'd3': '//cdnjs.cloudflare.com/ajax/libs/d3/4.2.1/d3.min',
//                 'topojson' : '//cdnjs.cloudflare.com/ajax/libs/topojson/1.6.20/topojson.min',
//                 'brunel' : 'https://brunelvis.org/js/brunel.2.3.min',
//                 'brunelControls' : 'https://brunelvis.org/js/brunel.controls.2.3.min'
//             },
//
//             shim: {
//                'brunel' : {
//                     exports: 'BrunelD3',
//                     deps: ['d3', 'topojson'],
//                     init: function() {
//                        return {
//                          BrunelD3 : BrunelD3,
//                          BrunelData : BrunelData
//                       }
//                     }
//                 },
//                'brunelControls' : {
//                     exports: 'BrunelEventHandlers',
//                     init: function() {
//                        return {
//                          BrunelEventHandlers: BrunelEventHandlers,
//                          BrunelJQueryControlFactory: BrunelJQueryControlFactory
//                       }
//                     }
//                 }
//
//             }
//
//         });
//
//         require(["d3"], function(d3) {
//         require(["brunel", "brunelControls"], function(brunel, brunelControls) {
//
//             function  BrunelVis(visId) {
//   "use strict";                                                                       // strict mode
//   var datasets = [],                                      // array of datasets for the original data
//       pre = function(d, i) { return d },                         // default pre-process does nothing
//       post = function(d, i) { return d },                       // default post-process does nothing
//       transitionTime = 200,                                        // transition time for animations
//       charts = [],                                                       // the charts in the system
//       vis = d3.select('#' + visId).attr('class', 'brunel');                     // the SVG container
//
//   BrunelD3.addDefinitions(vis);                                   // ensure standard symbols present
//
//   // Define chart #1 in the visualization //////////////////////////////////////////////////////////
//
//   charts[0] = function(parentNode, filterRows) {
//     var geom = BrunelD3.geometry(parentNode || vis.node(), 0, 0, 1, 1, 5, 65, 37, 118),
//       elements = [];                                              // array of elements in this chart
//
//     // Define groups for the chart parts ///////////////////////////////////////////////////////////
//
//     var chart =  vis.append('g').attr('class', 'chart1')
//       .attr('transform','translate(' + geom.chart_left + ',' + geom.chart_top + ')');
//     var overlay = chart.append('g').attr('class', 'element').attr('class', 'overlay');
//     var zoom = d3.zoom().scaleExtent([1/3,3]);
//     var zoomNode = overlay.append('rect').attr('class', 'overlay')
//       .attr('x', geom.inner_left).attr('y', geom.inner_top)
//       .attr('width', geom.inner_rawWidth).attr('height', geom.inner_rawHeight)
//       .style('cursor', 'move').call(zoom)
//       .node();
//     zoomNode.__zoom = d3.zoomIdentity;
//     chart.append('rect').attr('class', 'background').attr('width', geom.chart_right-geom.chart_left).attr('height', geom.chart_bottom-geom.chart_top);
//     var interior = chart.append('g').attr('class', 'interior zoomNone')
//       .attr('transform','translate(' + geom.inner_left + ',' + geom.inner_top + ')')
//       .attr('clip-path', 'url(#clip_visiddc72168b-af3f-4e53-b0d4-687ee816c534_chart1_inner)');
//     interior.append('rect').attr('class', 'inner').attr('width', geom.inner_width).attr('height', geom.inner_height);
//     var gridGroup = interior.append('g').attr('class', 'grid');
//     var axes = chart.append('g').attr('class', 'axis')
//       .attr('transform','translate(' + geom.inner_left + ',' + geom.inner_top + ')');
//     var legends = chart.append('g').attr('class', 'legend')
//       .attr('transform','translate(' + (geom.chart_right-geom.chart_left - 3) + ',' + 0 + ')');
//     vis.append('clipPath').attr('id', 'clip_visiddc72168b-af3f-4e53-b0d4-687ee816c534_chart1_inner').append('rect')
//       .attr('x', 0).attr('y', 0)
//       .attr('width', geom.inner_rawWidth+1).attr('height', geom.inner_rawHeight+1);
//
//     // Scales //////////////////////////////////////////////////////////////////////////////////////
//
//     var scale_x = d3.scaleLinear().domain([10, 80.000007])
//       .range([0, geom.inner_width]);
//     var scale_inner = d3.scaleLinear().domain([0,1])
//       .range([-0.5, 0.5]);
//     var scale_y = d3.scaleSqrt().domain([0, 600000.06])
//       .range([geom.inner_height, 0]);
//     var base_scales = [scale_x, scale_y];                           // untransformed original scales
//
//     // Axes ////////////////////////////////////////////////////////////////////////////////////////
//
//     axes.append('g').attr('class', 'x axis')
//       .attr('transform','translate(0,' + geom.inner_rawHeight + ')')
//       .attr('clip-path', 'url(#clip_visiddc72168b-af3f-4e53-b0d4-687ee816c534_chart1_haxis)');
//     vis.append('clipPath').attr('id', 'clip_visiddc72168b-af3f-4e53-b0d4-687ee816c534_chart1_haxis').append('polyline')
//       .attr('points', '-1,-1000, -1,-1 -5,5, -1000,5, -100,1000, 10000,1000 10000,-1000');
//     axes.select('g.axis.x').append('text').attr('class', 'title').text('AGE').style('text-anchor', 'middle')
//       .attr('x',geom.inner_rawWidth/2)
//       .attr('y', geom.inner_bottom - 2.0).attr('dy','-0.27em');
//     axes.append('g').attr('class', 'y axis')
//       .attr('clip-path', 'url(#clip_visiddc72168b-af3f-4e53-b0d4-687ee816c534_chart1_vaxis)');
//     vis.append('clipPath').attr('id', 'clip_visiddc72168b-af3f-4e53-b0d4-687ee816c534_chart1_vaxis').append('polyline')
//       .attr('points', '-1000,-10000, 10000,-10000, 10000,' + (geom.inner_rawHeight+1) + ', -1,' + (geom.inner_rawHeight+1) + ', -1,' + (geom.inner_rawHeight+5) + ', -1000,' + (geom.inner_rawHeight+5) );
//     axes.select('g.axis.y').append('text').attr('class', 'title').text('INCOME').style('text-anchor', 'middle')
//       .attr('x',-geom.inner_rawHeight/2)
//       .attr('y', 4-geom.inner_left).attr('dy', '0.7em').attr('transform', 'rotate(270)');
//
//     var axis_bottom = d3.axisBottom(scale_x).ticks(Math.min(10, Math.round(geom.inner_width / 33.0)));
//     var axis_left = d3.axisLeft(scale_y).ticks(Math.min(10, Math.round(geom.inner_width / 20)));
//
//     function buildAxes(time) {
//       var axis_x = axes.select('g.axis.x');
//       BrunelD3.transition(axis_x, time).call(axis_bottom.scale(scale_x));
//       var axis_y = axes.select('g.axis.y');
//       BrunelD3.transition(axis_y, time).call(axis_left.scale(scale_y));
//     }
//     zoom.on('zoom', function(t, time) {
//         t = t ||BrunelD3.restrictZoom(d3.event.transform, geom, this);
//         scale_x = t.rescaleX(base_scales[0]);
//         scale_y = t.rescaleY(base_scales[1]);
//         zoomNode.__zoom = t;
//         interior.attr('class', 'interior ' + BrunelD3.zoomLabel(t.k));;
//         build(time || -1);
//     });
//
//     // Define element #1 ///////////////////////////////////////////////////////////////////////////
//
//     elements[0] = function() {
//       var original, processed,                           // data sets passed in and then transformed
//         element, data,                                 // brunel element information and brunel data
//         selection, merged;                                      // d3 selection and merged selection
//       var elementGroup = interior.append('g').attr('class', 'element1'),
//         main = elementGroup.append('g').attr('class',

// %%
%%brunel 
data('df') bar color (CreditReimbursed) x(Age) y(#count) stack tooltip(#all) axes(x:'Age' ,y:'# Credit')
// Out:
//          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/brunel.2.3.css" charset="utf-8">
//          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/sumoselect.css" charset="utf-8">
//          <style>  </style>
//          <div id="controlsId9eba85da-27c9-40ea-baf6-448acef1bb6d" class="brunel"/>
// <svg id="visid7079f0dc-d225-4571-bc71-fffb1be36c7a" width="500" height="400"></svg>
//
// <script>
// require.config({
//             waitSeconds: 60,
//             paths: {
//                 'd3': '//cdnjs.cloudflare.com/ajax/libs/d3/4.2.1/d3.min',
//                 'topojson' : '//cdnjs.cloudflare.com/ajax/libs/topojson/1.6.20/topojson.min',
//                 'brunel' : 'https://brunelvis.org/js/brunel.2.3.min',
//                 'brunelControls' : 'https://brunelvis.org/js/brunel.controls.2.3.min'
//             },
//
//             shim: {
//                'brunel' : {
//                     exports: 'BrunelD3',
//                     deps: ['d3', 'topojson'],
//                     init: function() {
//                        return {
//                          BrunelD3 : BrunelD3,
//                          BrunelData : BrunelData
//                       }
//                     }
//                 },
//                'brunelControls' : {
//                     exports: 'BrunelEventHandlers',
//                     init: function() {
//                        return {
//                          BrunelEventHandlers: BrunelEventHandlers,
//                          BrunelJQueryControlFactory: BrunelJQueryControlFactory
//                       }
//                     }
//                 }
//
//             }
//
//         });
//
//         require(["d3"], function(d3) {
//         require(["brunel", "brunelControls"], function(brunel, brunelControls) {
//
//             function  BrunelVis(visId) {
//   "use strict";                                                                       // strict mode
//   var datasets = [],                                      // array of datasets for the original data
//       pre = function(d, i) { return d },                         // default pre-process does nothing
//       post = function(d, i) { return d },                       // default post-process does nothing
//       transitionTime = 200,                                        // transition time for animations
//       charts = [],                                                       // the charts in the system
//       vis = d3.select('#' + visId).attr('class', 'brunel');                     // the SVG container
//
//   BrunelD3.addDefinitions(vis);                                   // ensure standard symbols present
//
//   // Define chart #1 in the visualization //////////////////////////////////////////////////////////
//
//   charts[0] = function(parentNode, filterRows) {
//     var geom = BrunelD3.geometry(parentNode || vis.node(), 0, 0, 1, 1, 5, 43, 37, 118),
//       elements = [];                                              // array of elements in this chart
//
//     // Define groups for the chart parts ///////////////////////////////////////////////////////////
//
//     var chart =  vis.append('g').attr('class', 'chart1')
//       .attr('transform','translate(' + geom.chart_left + ',' + geom.chart_top + ')');
//     var overlay = chart.append('g').attr('class', 'element').attr('class', 'overlay');
//     var zoom = d3.zoom().scaleExtent([1/3,3]);
//     var zoomNode = overlay.append('rect').attr('class', 'overlay')
//       .attr('x', geom.inner_left).attr('y', geom.inner_top)
//       .attr('width', geom.inner_rawWidth).attr('height', geom.inner_rawHeight)
//       .style('cursor', 'move').call(zoom)
//       .node();
//     zoomNode.__zoom = d3.zoomIdentity;
//     chart.append('rect').attr('class', 'background').attr('width', geom.chart_right-geom.chart_left).attr('height', geom.chart_bottom-geom.chart_top);
//     var interior = chart.append('g').attr('class', 'interior zoomNone')
//       .attr('transform','translate(' + geom.inner_left + ',' + geom.inner_top + ')')
//       .attr('clip-path', 'url(#clip_visid7079f0dc-d225-4571-bc71-fffb1be36c7a_chart1_inner)');
//     interior.append('rect').attr('class', 'inner').attr('width', geom.inner_width).attr('height', geom.inner_height);
//     var gridGroup = interior.append('g').attr('class', 'grid');
//     var axes = chart.append('g').attr('class', 'axis')
//       .attr('transform','translate(' + geom.inner_left + ',' + geom.inner_top + ')');
//     var legends = chart.append('g').attr('class', 'legend')
//       .attr('transform','translate(' + (geom.chart_right-geom.chart_left - 3) + ',' + 0 + ')');
//     vis.append('clipPath').attr('id', 'clip_visid7079f0dc-d225-4571-bc71-fffb1be36c7a_chart1_inner').append('rect')
//       .attr('x', 0).attr('y', 0)
//       .attr('width', geom.inner_rawWidth+1).attr('height', geom.inner_rawHeight+1);
//
//     // Scales //////////////////////////////////////////////////////////////////////////////////////
//
//     var scale_x = d3.scaleLinear().domain([15, 65.000005])
//       .range([0, geom.inner_width]);
//     var scale_inner = d3.scaleLinear().domain([0,1])
//       .range([-0.5, 0.5]);
//     var scale_y = d3.scaleLinear().domain([0, 140.00001])
//       .range([geom.inner_height, 0]);
//     var base_scales = [scale_x, scale_y];                           // untransformed original scales
//
//     // Axes ////////////////////////////////////////////////////////////////////////////////////////
//
//     axes.append('g').attr('class', 'x axis')
//       .attr('transform','translate(0,' + geom.inner_rawHeight + ')')
//       .attr('clip-path', 'url(#clip_visid7079f0dc-d225-4571-bc71-fffb1be36c7a_chart1_haxis)');
//     vis.append('clipPath').attr('id', 'clip_visid7079f0dc-d225-4571-bc71-fffb1be36c7a_chart1_haxis').append('polyline')
//       .attr('points', '-1,-1000, -1,-1 -5,5, -1000,5, -100,1000, 10000,1000 10000,-1000');
//     axes.select('g.axis.x').append('text').attr('class', 'title').text('Age').style('text-anchor', 'middle')
//       .attr('x',geom.inner_rawWidth/2)
//       .attr('y', geom.inner_bottom - 2.0).attr('dy','-0.27em');
//     axes.append('g').attr('class', 'y axis')
//       .attr('clip-path', 'url(#clip_visid7079f0dc-d225-4571-bc71-fffb1be36c7a_chart1_vaxis)');
//     vis.append('clipPath').attr('id', 'clip_visid7079f0dc-d225-4571-bc71-fffb1be36c7a_chart1_vaxis').append('polyline')
//       .attr('points', '-1000,-10000, 10000,-10000, 10000,' + (geom.inner_rawHeight+1) + ', -1,' + (geom.inner_rawHeight+1) + ', -1,' + (geom.inner_rawHeight+5) + ', -1000,' + (geom.inner_rawHeight+5) );
//     axes.select('g.axis.y').append('text').attr('class', 'title').text('# Credit').style('text-anchor', 'middle')
//       .attr('x',-geom.inner_rawHeight/2)
//       .attr('y', 4-geom.inner_left).attr('dy', '0.7em').attr('transform', 'rotate(270)');
//
//     var axis_bottom = d3.axisBottom(scale_x).ticks(Math.min(10, Math.round(geom.inner_width / 33.0)));
//     var axis_left = d3.axisLeft(scale_y).ticks(Math.min(10, Math.round(geom.inner_width / 20)));
//
//     function buildAxes(time) {
//       var axis_x = axes.select('g.axis.x');
//       BrunelD3.transition(axis_x, time).call(axis_bottom.scale(scale_x));
//       var axis_y = axes.select('g.axis.y');
//       BrunelD3.transition(axis_y, time).call(axis_left.scale(scale_y));
//     }
//     zoom.on('zoom', function(t, time) {
//         t = t ||BrunelD3.restrictZoom(d3.event.transform, geom, this);
//         scale_x = t.rescaleX(base_scales[0]);
//         scale_y = t.rescaleY(base_scales[1]);
//         zoomNode.__zoom = t;
//         interior.attr('class', 'interior ' + BrunelD3.zoomLabel(t.k));;
//         build(time || -1);
//     });
//
//     // Define element #1 ///////////////////////////////////////////////////////////////////////////
//
//     elements[0] = function() {
//       var original, processed,                           // data sets passed in and then transformed
//         element, data,                                 // brunel element information and brunel data
//         selection, merged;                                      // d3 selection and merged selection
//       var elementGroup = interior.append('g').attr('class', 'element1'),
//         main = elementGroup.append('g').attr('cla

// %%
%%brunel 
data('df') bar color (CreditReimbursed) x(cards) y(#count) stack tooltip(#all) axes(x:'Number Credit Card' ,y:'Number of Credit')
// Out:
//          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/brunel.2.3.css" charset="utf-8">
//          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/sumoselect.css" charset="utf-8">
//          <style>  </style>
//          <div id="controlsId88cb0464-cbce-4fb2-b79d-05d0f28e5ddf" class="brunel"/>
// <svg id="viside5f5c2be-8d35-4544-8d1c-217d28ff7209" width="500" height="400"></svg>
//
// <script>
// require.config({
//             waitSeconds: 60,
//             paths: {
//                 'd3': '//cdnjs.cloudflare.com/ajax/libs/d3/4.2.1/d3.min',
//                 'topojson' : '//cdnjs.cloudflare.com/ajax/libs/topojson/1.6.20/topojson.min',
//                 'brunel' : 'https://brunelvis.org/js/brunel.2.3.min',
//                 'brunelControls' : 'https://brunelvis.org/js/brunel.controls.2.3.min'
//             },
//
//             shim: {
//                'brunel' : {
//                     exports: 'BrunelD3',
//                     deps: ['d3', 'topojson'],
//                     init: function() {
//                        return {
//                          BrunelD3 : BrunelD3,
//                          BrunelData : BrunelData
//                       }
//                     }
//                 },
//                'brunelControls' : {
//                     exports: 'BrunelEventHandlers',
//                     init: function() {
//                        return {
//                          BrunelEventHandlers: BrunelEventHandlers,
//                          BrunelJQueryControlFactory: BrunelJQueryControlFactory
//                       }
//                     }
//                 }
//
//             }
//
//         });
//
//         require(["d3"], function(d3) {
//         require(["brunel", "brunelControls"], function(brunel, brunelControls) {
//
//             function  BrunelVis(visId) {
//   "use strict";                                                                       // strict mode
//   var datasets = [],                                      // array of datasets for the original data
//       pre = function(d, i) { return d },                         // default pre-process does nothing
//       post = function(d, i) { return d },                       // default post-process does nothing
//       transitionTime = 200,                                        // transition time for animations
//       charts = [],                                                       // the charts in the system
//       vis = d3.select('#' + visId).attr('class', 'brunel');                     // the SVG container
//
//   BrunelD3.addDefinitions(vis);                                   // ensure standard symbols present
//
//   // Define chart #1 in the visualization //////////////////////////////////////////////////////////
//
//   charts[0] = function(parentNode, filterRows) {
//     var geom = BrunelD3.geometry(parentNode || vis.node(), 0, 0, 1, 1, 5, 43, 37, 118),
//       elements = [];                                              // array of elements in this chart
//
//     // Define groups for the chart parts ///////////////////////////////////////////////////////////
//
//     var chart =  vis.append('g').attr('class', 'chart1')
//       .attr('transform','translate(' + geom.chart_left + ',' + geom.chart_top + ')');
//     var overlay = chart.append('g').attr('class', 'element').attr('class', 'overlay');
//     var zoom = d3.zoom().scaleExtent([1/3,3]);
//     var zoomNode = overlay.append('rect').attr('class', 'overlay')
//       .attr('x', geom.inner_left).attr('y', geom.inner_top)
//       .attr('width', geom.inner_rawWidth).attr('height', geom.inner_rawHeight)
//       .style('cursor', 'move').call(zoom)
//       .node();
//     zoomNode.__zoom = d3.zoomIdentity;
//     chart.append('rect').attr('class', 'background').attr('width', geom.chart_right-geom.chart_left).attr('height', geom.chart_bottom-geom.chart_top);
//     var interior = chart.append('g').attr('class', 'interior zoomNone')
//       .attr('transform','translate(' + geom.inner_left + ',' + geom.inner_top + ')')
//       .attr('clip-path', 'url(#clip_viside5f5c2be-8d35-4544-8d1c-217d28ff7209_chart1_inner)');
//     interior.append('rect').attr('class', 'inner').attr('width', geom.inner_width).attr('height', geom.inner_height);
//     var gridGroup = interior.append('g').attr('class', 'grid');
//     var axes = chart.append('g').attr('class', 'axis')
//       .attr('transform','translate(' + geom.inner_left + ',' + geom.inner_top + ')');
//     var legends = chart.append('g').attr('class', 'legend')
//       .attr('transform','translate(' + (geom.chart_right-geom.chart_left - 3) + ',' + 0 + ')');
//     vis.append('clipPath').attr('id', 'clip_viside5f5c2be-8d35-4544-8d1c-217d28ff7209_chart1_inner').append('rect')
//       .attr('x', 0).attr('y', 0)
//       .attr('width', geom.inner_rawWidth+1).attr('height', geom.inner_rawHeight+1);
//
//     // Scales //////////////////////////////////////////////////////////////////////////////////////
//
//     var scale_x = d3.scaleLinear().domain([0.5, 5.5000005])
//       .range([0, geom.inner_width]);
//     var scale_inner = d3.scaleLinear().domain([0,1])
//       .range([-0.5, 0.5]);
//     var scale_y = d3.scaleLinear().domain([0, 600.00006])
//       .range([geom.inner_height, 0]);
//     var base_scales = [scale_x, scale_y];                           // untransformed original scales
//
//     // Axes ////////////////////////////////////////////////////////////////////////////////////////
//
//     axes.append('g').attr('class', 'x axis')
//       .attr('transform','translate(0,' + geom.inner_rawHeight + ')')
//       .attr('clip-path', 'url(#clip_viside5f5c2be-8d35-4544-8d1c-217d28ff7209_chart1_haxis)');
//     vis.append('clipPath').attr('id', 'clip_viside5f5c2be-8d35-4544-8d1c-217d28ff7209_chart1_haxis').append('polyline')
//       .attr('points', '-1,-1000, -1,-1 -5,5, -1000,5, -100,1000, 10000,1000 10000,-1000');
//     axes.select('g.axis.x').append('text').attr('class', 'title').text('Number Credit Card').style('text-anchor', 'middle')
//       .attr('x',geom.inner_rawWidth/2)
//       .attr('y', geom.inner_bottom - 2.0).attr('dy','-0.27em');
//     axes.append('g').attr('class', 'y axis')
//       .attr('clip-path', 'url(#clip_viside5f5c2be-8d35-4544-8d1c-217d28ff7209_chart1_vaxis)');
//     vis.append('clipPath').attr('id', 'clip_viside5f5c2be-8d35-4544-8d1c-217d28ff7209_chart1_vaxis').append('polyline')
//       .attr('points', '-1000,-10000, 10000,-10000, 10000,' + (geom.inner_rawHeight+1) + ', -1,' + (geom.inner_rawHeight+1) + ', -1,' + (geom.inner_rawHeight+5) + ', -1000,' + (geom.inner_rawHeight+5) );
//     axes.select('g.axis.y').append('text').attr('class', 'title').text('Number of Credit').style('text-anchor', 'middle')
//       .attr('x',-geom.inner_rawHeight/2)
//       .attr('y', 4-geom.inner_left).attr('dy', '0.7em').attr('transform', 'rotate(270)');
//
//     var axis_bottom = d3.axisBottom(scale_x).ticks(Math.min(10, Math.round(geom.inner_width / 33.0)));
//     var axis_left = d3.axisLeft(scale_y).ticks(Math.min(10, Math.round(geom.inner_width / 20)));
//
//     function buildAxes(time) {
//       var axis_x = axes.select('g.axis.x');
//       BrunelD3.transition(axis_x, time).call(axis_bottom.scale(scale_x));
//       var axis_y = axes.select('g.axis.y');
//       BrunelD3.transition(axis_y, time).call(axis_left.scale(scale_y));
//     }
//     zoom.on('zoom', function(t, time) {
//         t = t ||BrunelD3.restrictZoom(d3.event.transform, geom, this);
//         scale_x = t.rescaleX(base_scales[0]);
//         scale_y = t.rescaleY(base_scales[1]);
//         zoomNode.__zoom = t;
//         interior.attr('class', 'interior ' + BrunelD3.zoomLabel(t.k));;
//         build(time || -1);
//     });
//
//     // Define element #1 ///////////////////////////////////////////////////////////////////////////
//
//     elements[0] = function() {
//       var original, processed,                           // data sets passed in and then transformed
//         element, data,                                 // brunel element information and brunel data
//         selection, merged;                                      // d3 selection and merged selection
//       var elementGroup = interior.append('g').attr('class', 'element1'),
//         main = elementGro

// %%
%%brunel 
data('df') bar  x(cards) y(CreditReimbursed) mean(CreditReimbursed) stack axes(x:'#Number of credit cards' ,y:'Percent of reimbursed credit')
// Out:
//          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/brunel.2.3.css" charset="utf-8">
//          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/sumoselect.css" charset="utf-8">
//          <style>  </style>
//          <div id="controlsIdcd575118-4160-47aa-bb2a-a532eb7f03dd" class="brunel"/>
// <svg id="visid671ad1e9-cd5b-4908-ac79-8660d6aca1ec" width="500" height="400"></svg>
//
// <script>
// require.config({
//             waitSeconds: 60,
//             paths: {
//                 'd3': '//cdnjs.cloudflare.com/ajax/libs/d3/4.2.1/d3.min',
//                 'topojson' : '//cdnjs.cloudflare.com/ajax/libs/topojson/1.6.20/topojson.min',
//                 'brunel' : 'https://brunelvis.org/js/brunel.2.3.min',
//                 'brunelControls' : 'https://brunelvis.org/js/brunel.controls.2.3.min'
//             },
//
//             shim: {
//                'brunel' : {
//                     exports: 'BrunelD3',
//                     deps: ['d3', 'topojson'],
//                     init: function() {
//                        return {
//                          BrunelD3 : BrunelD3,
//                          BrunelData : BrunelData
//                       }
//                     }
//                 },
//                'brunelControls' : {
//                     exports: 'BrunelEventHandlers',
//                     init: function() {
//                        return {
//                          BrunelEventHandlers: BrunelEventHandlers,
//                          BrunelJQueryControlFactory: BrunelJQueryControlFactory
//                       }
//                     }
//                 }
//
//             }
//
//         });
//
//         require(["d3"], function(d3) {
//         require(["brunel", "brunelControls"], function(brunel, brunelControls) {
//
//             function  BrunelVis(visId) {
//   "use strict";                                                                       // strict mode
//   var datasets = [],                                      // array of datasets for the original data
//       pre = function(d, i) { return d },                         // default pre-process does nothing
//       post = function(d, i) { return d },                       // default post-process does nothing
//       transitionTime = 200,                                        // transition time for animations
//       charts = [],                                                       // the charts in the system
//       vis = d3.select('#' + visId).attr('class', 'brunel');                     // the SVG container
//
//   BrunelD3.addDefinitions(vis);                                   // ensure standard symbols present
//
//   // Define chart #1 in the visualization //////////////////////////////////////////////////////////
//
//   charts[0] = function(parentNode, filterRows) {
//     var geom = BrunelD3.geometry(parentNode || vis.node(), 0, 0, 1, 1, 5, 49, 37, 13),
//       elements = [];                                              // array of elements in this chart
//
//     // Define groups for the chart parts ///////////////////////////////////////////////////////////
//
//     var chart =  vis.append('g').attr('class', 'chart1')
//       .attr('transform','translate(' + geom.chart_left + ',' + geom.chart_top + ')');
//     var overlay = chart.append('g').attr('class', 'element').attr('class', 'overlay');
//     var zoom = d3.zoom().scaleExtent([1/3,3]);
//     var zoomNode = overlay.append('rect').attr('class', 'overlay')
//       .attr('x', geom.inner_left).attr('y', geom.inner_top)
//       .attr('width', geom.inner_rawWidth).attr('height', geom.inner_rawHeight)
//       .style('cursor', 'move').call(zoom)
//       .node();
//     zoomNode.__zoom = d3.zoomIdentity;
//     chart.append('rect').attr('class', 'background').attr('width', geom.chart_right-geom.chart_left).attr('height', geom.chart_bottom-geom.chart_top);
//     var interior = chart.append('g').attr('class', 'interior zoomNone')
//       .attr('transform','translate(' + geom.inner_left + ',' + geom.inner_top + ')')
//       .attr('clip-path', 'url(#clip_visid671ad1e9-cd5b-4908-ac79-8660d6aca1ec_chart1_inner)');
//     interior.append('rect').attr('class', 'inner').attr('width', geom.inner_width).attr('height', geom.inner_height);
//     var gridGroup = interior.append('g').attr('class', 'grid');
//     var axes = chart.append('g').attr('class', 'axis')
//       .attr('transform','translate(' + geom.inner_left + ',' + geom.inner_top + ')');
//     vis.append('clipPath').attr('id', 'clip_visid671ad1e9-cd5b-4908-ac79-8660d6aca1ec_chart1_inner').append('rect')
//       .attr('x', 0).attr('y', 0)
//       .attr('width', geom.inner_rawWidth+1).attr('height', geom.inner_rawHeight+1);
//
//     // Scales //////////////////////////////////////////////////////////////////////////////////////
//
//     var scale_x = d3.scaleLinear().domain([0.5, 5.5000005])
//       .range([0, geom.inner_width]);
//     var scale_inner = d3.scaleLinear().domain([0,1])
//       .range([-0.5, 0.5]);
//     var scale_y = d3.scaleLinear().domain([0, 1.0000001])
//       .range([geom.inner_height, 0]);
//     var base_scales = [scale_x, scale_y];                           // untransformed original scales
//
//     // Axes ////////////////////////////////////////////////////////////////////////////////////////
//
//     axes.append('g').attr('class', 'x axis')
//       .attr('transform','translate(0,' + geom.inner_rawHeight + ')')
//       .attr('clip-path', 'url(#clip_visid671ad1e9-cd5b-4908-ac79-8660d6aca1ec_chart1_haxis)');
//     vis.append('clipPath').attr('id', 'clip_visid671ad1e9-cd5b-4908-ac79-8660d6aca1ec_chart1_haxis').append('polyline')
//       .attr('points', '-1,-1000, -1,-1 -5,5, -1000,5, -100,1000, 10000,1000 10000,-1000');
//     axes.select('g.axis.x').append('text').attr('class', 'title').text('#Number of credit cards').style('text-anchor', 'middle')
//       .attr('x',geom.inner_rawWidth/2)
//       .attr('y', geom.inner_bottom - 2.0).attr('dy','-0.27em');
//     axes.append('g').attr('class', 'y axis')
//       .attr('clip-path', 'url(#clip_visid671ad1e9-cd5b-4908-ac79-8660d6aca1ec_chart1_vaxis)');
//     vis.append('clipPath').attr('id', 'clip_visid671ad1e9-cd5b-4908-ac79-8660d6aca1ec_chart1_vaxis').append('polyline')
//       .attr('points', '-1000,-10000, 10000,-10000, 10000,' + (geom.inner_rawHeight+1) + ', -1,' + (geom.inner_rawHeight+1) + ', -1,' + (geom.inner_rawHeight+5) + ', -1000,' + (geom.inner_rawHeight+5) );
//     axes.select('g.axis.y').append('text').attr('class', 'title').text('Percent of reimbursed credit').style('text-anchor', 'middle')
//       .attr('x',-geom.inner_rawHeight/2)
//       .attr('y', 4-geom.inner_left).attr('dy', '0.7em').attr('transform', 'rotate(270)');
//
//     var axis_bottom = d3.axisBottom(scale_x).ticks(Math.min(10, Math.round(geom.inner_width / 33.0)));
//     var axis_left = d3.axisLeft(scale_y).ticks(Math.min(10, Math.round(geom.inner_width / 20)));
//
//     function buildAxes(time) {
//       var axis_x = axes.select('g.axis.x');
//       BrunelD3.transition(axis_x, time).call(axis_bottom.scale(scale_x));
//       var axis_y = axes.select('g.axis.y');
//       BrunelD3.transition(axis_y, time).call(axis_left.scale(scale_y));
//     }
//     zoom.on('zoom', function(t, time) {
//         t = t ||BrunelD3.restrictZoom(d3.event.transform, geom, this);
//         scale_x = t.rescaleX(base_scales[0]);
//         scale_y = t.rescaleY(base_scales[1]);
//         zoomNode.__zoom = t;
//         interior.attr('class', 'interior ' + BrunelD3.zoomLabel(t.k));;
//         build(time || -1);
//     });
//
//     // Define element #1 ///////////////////////////////////////////////////////////////////////////
//
//     elements[0] = function() {
//       var original, processed,                           // data sets passed in and then transformed
//         element, data,                                 // brunel element information and brunel data
//         selection, merged;                                      // d3 selection and merged selection
//       var elementGroup = interior.append('g').attr('class', 'element1'),
//         main = elementGroup.append('g').attr('class', 'main'),
//         labels = BrunelD3.undoTransform(elementGroup.append('g').attr('class', 'labels').attr('aria-hi

// %%
%%brunel 
data('df') bar color (CreditReimbursed) x(CarLoans) y(#count) stack axes(x:'Number of loans' ,y:'Number of credit')
// Out:
//          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/brunel.2.3.css" charset="utf-8">
//          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/sumoselect.css" charset="utf-8">
//          <style>  </style>
//          <div id="controlsId5bbd0f37-7d5f-4d74-b315-1c62f59e6e19" class="brunel"/>
// <svg id="visid4bc2d887-860a-4a37-a8f8-903461aa0115" width="500" height="400"></svg>
//
// <script>
// require.config({
//             waitSeconds: 60,
//             paths: {
//                 'd3': '//cdnjs.cloudflare.com/ajax/libs/d3/4.2.1/d3.min',
//                 'topojson' : '//cdnjs.cloudflare.com/ajax/libs/topojson/1.6.20/topojson.min',
//                 'brunel' : 'https://brunelvis.org/js/brunel.2.3.min',
//                 'brunelControls' : 'https://brunelvis.org/js/brunel.controls.2.3.min'
//             },
//
//             shim: {
//                'brunel' : {
//                     exports: 'BrunelD3',
//                     deps: ['d3', 'topojson'],
//                     init: function() {
//                        return {
//                          BrunelD3 : BrunelD3,
//                          BrunelData : BrunelData
//                       }
//                     }
//                 },
//                'brunelControls' : {
//                     exports: 'BrunelEventHandlers',
//                     init: function() {
//                        return {
//                          BrunelEventHandlers: BrunelEventHandlers,
//                          BrunelJQueryControlFactory: BrunelJQueryControlFactory
//                       }
//                     }
//                 }
//
//             }
//
//         });
//
//         require(["d3"], function(d3) {
//         require(["brunel", "brunelControls"], function(brunel, brunelControls) {
//
//             function  BrunelVis(visId) {
//   "use strict";                                                                       // strict mode
//   var datasets = [],                                      // array of datasets for the original data
//       pre = function(d, i) { return d },                         // default pre-process does nothing
//       post = function(d, i) { return d },                       // default post-process does nothing
//       transitionTime = 200,                                        // transition time for animations
//       charts = [],                                                       // the charts in the system
//       vis = d3.select('#' + visId).attr('class', 'brunel');                     // the SVG container
//
//   BrunelD3.addDefinitions(vis);                                   // ensure standard symbols present
//
//   // Define chart #1 in the visualization //////////////////////////////////////////////////////////
//
//   charts[0] = function(parentNode, filterRows) {
//     var geom = BrunelD3.geometry(parentNode || vis.node(), 0, 0, 1, 1, 5, 43, 37, 118),
//       elements = [];                                              // array of elements in this chart
//
//     // Define groups for the chart parts ///////////////////////////////////////////////////////////
//
//     var chart =  vis.append('g').attr('class', 'chart1')
//       .attr('transform','translate(' + geom.chart_left + ',' + geom.chart_top + ')');
//     var overlay = chart.append('g').attr('class', 'element').attr('class', 'overlay');
//     var zoom = d3.zoom().scaleExtent([1/3,3]);
//     var zoomNode = overlay.append('rect').attr('class', 'overlay')
//       .attr('x', geom.inner_left).attr('y', geom.inner_top)
//       .attr('width', geom.inner_rawWidth).attr('height', geom.inner_rawHeight)
//       .style('cursor', 'move').call(zoom)
//       .node();
//     zoomNode.__zoom = d3.zoomIdentity;
//     chart.append('rect').attr('class', 'background').attr('width', geom.chart_right-geom.chart_left).attr('height', geom.chart_bottom-geom.chart_top);
//     var interior = chart.append('g').attr('class', 'interior zoomNone')
//       .attr('transform','translate(' + geom.inner_left + ',' + geom.inner_top + ')')
//       .attr('clip-path', 'url(#clip_visid4bc2d887-860a-4a37-a8f8-903461aa0115_chart1_inner)');
//     interior.append('rect').attr('class', 'inner').attr('width', geom.inner_width).attr('height', geom.inner_height);
//     var gridGroup = interior.append('g').attr('class', 'grid');
//     var axes = chart.append('g').attr('class', 'axis')
//       .attr('transform','translate(' + geom.inner_left + ',' + geom.inner_top + ')');
//     var legends = chart.append('g').attr('class', 'legend')
//       .attr('transform','translate(' + (geom.chart_right-geom.chart_left - 3) + ',' + 0 + ')');
//     vis.append('clipPath').attr('id', 'clip_visid4bc2d887-860a-4a37-a8f8-903461aa0115_chart1_inner').append('rect')
//       .attr('x', 0).attr('y', 0)
//       .attr('width', geom.inner_rawWidth+1).attr('height', geom.inner_rawHeight+1);
//
//     // Scales //////////////////////////////////////////////////////////////////////////////////////
//
//     var scale_x = d3.scaleLinear().domain([-0.5, 3.5000004])
//       .range([0, geom.inner_width]);
//     var scale_inner = d3.scaleLinear().domain([0,1])
//       .range([-0.5, 0.5]);
//     var scale_y = d3.scaleLinear().domain([0, 900.00009])
//       .range([geom.inner_height, 0]);
//     var base_scales = [scale_x, scale_y];                           // untransformed original scales
//
//     // Axes ////////////////////////////////////////////////////////////////////////////////////////
//
//     axes.append('g').attr('class', 'x axis')
//       .attr('transform','translate(0,' + geom.inner_rawHeight + ')')
//       .attr('clip-path', 'url(#clip_visid4bc2d887-860a-4a37-a8f8-903461aa0115_chart1_haxis)');
//     vis.append('clipPath').attr('id', 'clip_visid4bc2d887-860a-4a37-a8f8-903461aa0115_chart1_haxis').append('polyline')
//       .attr('points', '-1,-1000, -1,-1 -5,5, -1000,5, -100,1000, 10000,1000 10000,-1000');
//     axes.select('g.axis.x').append('text').attr('class', 'title').text('Number of loans').style('text-anchor', 'middle')
//       .attr('x',geom.inner_rawWidth/2)
//       .attr('y', geom.inner_bottom - 2.0).attr('dy','-0.27em');
//     axes.append('g').attr('class', 'y axis')
//       .attr('clip-path', 'url(#clip_visid4bc2d887-860a-4a37-a8f8-903461aa0115_chart1_vaxis)');
//     vis.append('clipPath').attr('id', 'clip_visid4bc2d887-860a-4a37-a8f8-903461aa0115_chart1_vaxis').append('polyline')
//       .attr('points', '-1000,-10000, 10000,-10000, 10000,' + (geom.inner_rawHeight+1) + ', -1,' + (geom.inner_rawHeight+1) + ', -1,' + (geom.inner_rawHeight+5) + ', -1000,' + (geom.inner_rawHeight+5) );
//     axes.select('g.axis.y').append('text').attr('class', 'title').text('Number of credit').style('text-anchor', 'middle')
//       .attr('x',-geom.inner_rawHeight/2)
//       .attr('y', 4-geom.inner_left).attr('dy', '0.7em').attr('transform', 'rotate(270)');
//
//     var axis_bottom = d3.axisBottom(scale_x).ticks(Math.min(10, Math.round(geom.inner_width / 33.0)));
//     var axis_left = d3.axisLeft(scale_y).ticks(Math.min(10, Math.round(geom.inner_width / 20)));
//
//     function buildAxes(time) {
//       var axis_x = axes.select('g.axis.x');
//       BrunelD3.transition(axis_x, time).call(axis_bottom.scale(scale_x));
//       var axis_y = axes.select('g.axis.y');
//       BrunelD3.transition(axis_y, time).call(axis_left.scale(scale_y));
//     }
//     zoom.on('zoom', function(t, time) {
//         t = t ||BrunelD3.restrictZoom(d3.event.transform, geom, this);
//         scale_x = t.rescaleX(base_scales[0]);
//         scale_y = t.rescaleY(base_scales[1]);
//         zoomNode.__zoom = t;
//         interior.attr('class', 'interior ' + BrunelD3.zoomLabel(t.k));;
//         build(time || -1);
//     });
//
//     // Define element #1 ///////////////////////////////////////////////////////////////////////////
//
//     elements[0] = function() {
//       var original, processed,                           // data sets passed in and then transformed
//         element, data,                                 // brunel element information and brunel data
//         selection, merged;                                      // d3 selection and merged selection
//       var elementGroup = interior.append('g').attr('class', 'element1'),
//         main = elementGroup

// %%
%%brunel 
data('df') bar  x(CarLoans) y(CreditReimbursed) mean(CreditReimbursed) stack axes(x:'Number of loans' ,y:'Percent of reimbursed credit')
// Out:
//          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/brunel.2.3.css" charset="utf-8">
//          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/sumoselect.css" charset="utf-8">
//          <style>  </style>
//          <div id="controlsId4a80558f-cfbb-4394-bd36-3cad90252266" class="brunel"/>
// <svg id="visidb52a3ac5-b345-435e-9bce-1a3cd87678b6" width="500" height="400"></svg>
//
// <script>
// require.config({
//             waitSeconds: 60,
//             paths: {
//                 'd3': '//cdnjs.cloudflare.com/ajax/libs/d3/4.2.1/d3.min',
//                 'topojson' : '//cdnjs.cloudflare.com/ajax/libs/topojson/1.6.20/topojson.min',
//                 'brunel' : 'https://brunelvis.org/js/brunel.2.3.min',
//                 'brunelControls' : 'https://brunelvis.org/js/brunel.controls.2.3.min'
//             },
//
//             shim: {
//                'brunel' : {
//                     exports: 'BrunelD3',
//                     deps: ['d3', 'topojson'],
//                     init: function() {
//                        return {
//                          BrunelD3 : BrunelD3,
//                          BrunelData : BrunelData
//                       }
//                     }
//                 },
//                'brunelControls' : {
//                     exports: 'BrunelEventHandlers',
//                     init: function() {
//                        return {
//                          BrunelEventHandlers: BrunelEventHandlers,
//                          BrunelJQueryControlFactory: BrunelJQueryControlFactory
//                       }
//                     }
//                 }
//
//             }
//
//         });
//
//         require(["d3"], function(d3) {
//         require(["brunel", "brunelControls"], function(brunel, brunelControls) {
//
//             function  BrunelVis(visId) {
//   "use strict";                                                                       // strict mode
//   var datasets = [],                                      // array of datasets for the original data
//       pre = function(d, i) { return d },                         // default pre-process does nothing
//       post = function(d, i) { return d },                       // default post-process does nothing
//       transitionTime = 200,                                        // transition time for animations
//       charts = [],                                                       // the charts in the system
//       vis = d3.select('#' + visId).attr('class', 'brunel');                     // the SVG container
//
//   BrunelD3.addDefinitions(vis);                                   // ensure standard symbols present
//
//   // Define chart #1 in the visualization //////////////////////////////////////////////////////////
//
//   charts[0] = function(parentNode, filterRows) {
//     var geom = BrunelD3.geometry(parentNode || vis.node(), 0, 0, 1, 1, 5, 49, 37, 13),
//       elements = [];                                              // array of elements in this chart
//
//     // Define groups for the chart parts ///////////////////////////////////////////////////////////
//
//     var chart =  vis.append('g').attr('class', 'chart1')
//       .attr('transform','translate(' + geom.chart_left + ',' + geom.chart_top + ')');
//     var overlay = chart.append('g').attr('class', 'element').attr('class', 'overlay');
//     var zoom = d3.zoom().scaleExtent([1/3,3]);
//     var zoomNode = overlay.append('rect').attr('class', 'overlay')
//       .attr('x', geom.inner_left).attr('y', geom.inner_top)
//       .attr('width', geom.inner_rawWidth).attr('height', geom.inner_rawHeight)
//       .style('cursor', 'move').call(zoom)
//       .node();
//     zoomNode.__zoom = d3.zoomIdentity;
//     chart.append('rect').attr('class', 'background').attr('width', geom.chart_right-geom.chart_left).attr('height', geom.chart_bottom-geom.chart_top);
//     var interior = chart.append('g').attr('class', 'interior zoomNone')
//       .attr('transform','translate(' + geom.inner_left + ',' + geom.inner_top + ')')
//       .attr('clip-path', 'url(#clip_visidb52a3ac5-b345-435e-9bce-1a3cd87678b6_chart1_inner)');
//     interior.append('rect').attr('class', 'inner').attr('width', geom.inner_width).attr('height', geom.inner_height);
//     var gridGroup = interior.append('g').attr('class', 'grid');
//     var axes = chart.append('g').attr('class', 'axis')
//       .attr('transform','translate(' + geom.inner_left + ',' + geom.inner_top + ')');
//     vis.append('clipPath').attr('id', 'clip_visidb52a3ac5-b345-435e-9bce-1a3cd87678b6_chart1_inner').append('rect')
//       .attr('x', 0).attr('y', 0)
//       .attr('width', geom.inner_rawWidth+1).attr('height', geom.inner_rawHeight+1);
//
//     // Scales //////////////////////////////////////////////////////////////////////////////////////
//
//     var scale_x = d3.scaleLinear().domain([-0.5, 3.5000004])
//       .range([0, geom.inner_width]);
//     var scale_inner = d3.scaleLinear().domain([0,1])
//       .range([-0.5, 0.5]);
//     var scale_y = d3.scaleLinear().domain([0, 1.0000001])
//       .range([geom.inner_height, 0]);
//     var base_scales = [scale_x, scale_y];                           // untransformed original scales
//
//     // Axes ////////////////////////////////////////////////////////////////////////////////////////
//
//     axes.append('g').attr('class', 'x axis')
//       .attr('transform','translate(0,' + geom.inner_rawHeight + ')')
//       .attr('clip-path', 'url(#clip_visidb52a3ac5-b345-435e-9bce-1a3cd87678b6_chart1_haxis)');
//     vis.append('clipPath').attr('id', 'clip_visidb52a3ac5-b345-435e-9bce-1a3cd87678b6_chart1_haxis').append('polyline')
//       .attr('points', '-1,-1000, -1,-1 -5,5, -1000,5, -100,1000, 10000,1000 10000,-1000');
//     axes.select('g.axis.x').append('text').attr('class', 'title').text('Number of loans').style('text-anchor', 'middle')
//       .attr('x',geom.inner_rawWidth/2)
//       .attr('y', geom.inner_bottom - 2.0).attr('dy','-0.27em');
//     axes.append('g').attr('class', 'y axis')
//       .attr('clip-path', 'url(#clip_visidb52a3ac5-b345-435e-9bce-1a3cd87678b6_chart1_vaxis)');
//     vis.append('clipPath').attr('id', 'clip_visidb52a3ac5-b345-435e-9bce-1a3cd87678b6_chart1_vaxis').append('polyline')
//       .attr('points', '-1000,-10000, 10000,-10000, 10000,' + (geom.inner_rawHeight+1) + ', -1,' + (geom.inner_rawHeight+1) + ', -1,' + (geom.inner_rawHeight+5) + ', -1000,' + (geom.inner_rawHeight+5) );
//     axes.select('g.axis.y').append('text').attr('class', 'title').text('Percent of reimbursed credit').style('text-anchor', 'middle')
//       .attr('x',-geom.inner_rawHeight/2)
//       .attr('y', 4-geom.inner_left).attr('dy', '0.7em').attr('transform', 'rotate(270)');
//
//     var axis_bottom = d3.axisBottom(scale_x).ticks(Math.min(10, Math.round(geom.inner_width / 33.0)));
//     var axis_left = d3.axisLeft(scale_y).ticks(Math.min(10, Math.round(geom.inner_width / 20)));
//
//     function buildAxes(time) {
//       var axis_x = axes.select('g.axis.x');
//       BrunelD3.transition(axis_x, time).call(axis_bottom.scale(scale_x));
//       var axis_y = axes.select('g.axis.y');
//       BrunelD3.transition(axis_y, time).call(axis_left.scale(scale_y));
//     }
//     zoom.on('zoom', function(t, time) {
//         t = t ||BrunelD3.restrictZoom(d3.event.transform, geom, this);
//         scale_x = t.rescaleX(base_scales[0]);
//         scale_y = t.rescaleY(base_scales[1]);
//         zoomNode.__zoom = t;
//         interior.attr('class', 'interior ' + BrunelD3.zoomLabel(t.k));;
//         build(time || -1);
//     });
//
//     // Define element #1 ///////////////////////////////////////////////////////////////////////////
//
//     elements[0] = function() {
//       var original, processed,                           // data sets passed in and then transformed
//         element, data,                                 // brunel element information and brunel data
//         selection, merged;                                      // d3 selection and merged selection
//       var elementGroup = interior.append('g').attr('class', 'element1'),
//         main = elementGroup.append('g').attr('class', 'main'),
//         labels = BrunelD3.undoTransform(elementGroup.append('g').attr('class', 'labels').attr('aria-hidden',

// %% [markdown]
// # Prepare Training & Testing Data

// %% [markdown]
// # Construct the feature vector

// %%
val educationIndexer = new StringIndexer().
setInputCol("EDUCATION").
setOutputCol("Education_Index")
val assembler = new VectorAssembler().setInputCols(Array("AGE","INCOME","CARDS","CARLOANS","Education_Index")).setOutputCol("features")

// %% [markdown]
// # IBMSparkpipeline

// %%
val train = 80
val test = 20
val splits = Sampling.trainingSplit(df, train, test)
val trainDF = splits._1
val testDF = splits._2
trainDF.cache()
println(trainDF.show(5))
// Out:
// +------+---+------+-----+-------------------+--------+----------------+
// |RATING|AGE|INCOME|CARDS|          EDUCATION|CARLOANS|CREDITREIMBURSED|
// +------+---+------+-----+-------------------+--------+----------------+
// |     0| 69| 41539|    1|      Master degree|       1|               0|
// |     1| 65| 20039|    2|    Bachelor degree|       1|               0|
// |     2| 60| 95750|    2|      Master degree|       1|               1|
// |     3| 61| 89598|    2|      Master degree|       1|               1|
// |     5| 62| 55821|    2|Professional degree|       1|               0|
// +------+---+------+-----+-------------------+--------+----------------+
// only showing top 5 rows
//
// ()

// %%
import org.apache.spark.ml.feature.SQLTransformer
val sqlTrans = new SQLTransformer().setStatement("SELECT AGE,INCOME,CARDS,EDUCATION,CARLOANS, CAST(CREDITREIMBURSED AS DOUBLE) AS label FROM __THIS__")
val IBMtrainDF =  sqlTrans.transform(trainDF).cache()

// %%
val lr = new LogisticRegression().setMaxIter(500).setRegParam(0.0001)
val pipeline = new IBMSparkPipeline().setStages(Array(educationIndexer,assembler,lr))
val model = pipeline.fit(IBMtrainDF)

// %% [markdown]
// # Save Model

// %%
Connections.setMetaServiceHost("http://10.3.58.47:12501")
model.save("TSOUSRxx/CreditScoringLogisticReg")
println("model saved successfully")
// Out:
// model saved successfully
